# %% [markdown]
# # Variable aleatoria
#
# >### Objetivo de la clase
# >Representar la distribución de una variable aleatoria discreta mediante el uso de software

# %% [markdown]
# ## Ejecuta con Ctrl-Enter la siguiente celda con funciones básicas

# %%
#Ejecuta con Ctrl-Enter para cargar funciones básicas
from trazadores import *
from visores import *
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Cambia `n = 3` y ejecuta
#
# Esta celda representa el arranque táctico con cachipún en **dos** esquina.
# Cambia el valor de `n` a `3` para encontrar los resultados posibles de jugar al cachipún en 3 esquinas.

# %%
#Cambia a n = 3
n = 2

#Listo, ejecuta con Ctrl-Enter
rutas(n)
# Out:
#     esquina1   esquina2
# 0    derecha    derecha
# 1    derecha      recto
# 2    derecha  izquierda
# 3      recto    derecha
# 4      recto      recto
# 5      recto  izquierda
# 6  izquierda    derecha
# 7  izquierda      recto
# 8  izquierda  izquierda

# %% [markdown]
# ## 1. Responde en la siguiente celda

# %% [markdown]
# Mira los resultados en la tabla para 3 esquinas y responde:
#
# - ¿Cuántas formas posibles hay de hacer el arranque táctico?
#
#   R:
#
# - ¿Cuántas formas de arrancar doblan a la izquierda en la esquina 2?
#
#   R:

# %% [markdown]
# ## Prueba con otro valor de `n`
#
# Vuelve a cambiar el número `n` para modelar el resultado con más esquinas. **No pruebes números mayores a 11** porque pueden exceder las capacidades de este computador.

# %%
#Cambia n = 1 por otros números
n = 1

#Listo, ejecuta con Ctrl-Enter
rutas(n)
# Out:
#     esquina1
# 0    derecha
# 1      recto
# 2  izquierda

# %% [markdown]
# ## 2. Responde en la siguiente celda

# %% [markdown]
# La tabla no siempre muestra todos los resultados. Si son muchos, se muestran unas pocas filas del principio y del final.
#
# - ¿Cómo puedes determinar cuántos resultados posibles son?
#
#   R:

# %% [markdown]
# ## ¿Cuál es mejor opción?
#
# Algunas opciones nos llevan más lejos de la comisaría que otras. Ejecuta la celda siguiente para ver un par de opciones en el mapa.

# %%
# Mira la secuencia en las 8 esquinas de estos dos caminos.
r_azul  = ['recto', 'recto', 'derecha', 'recto', 'derecha', 'derecha', 'izquierda', 'recto']
r_verde = ['izquierda', 'derecha', 'recto', 'recto', 'izquierda', 'derecha', 'derecha', 'recto']

# Déjalos tal cuál y ejecuta con Ctrl-Enter

p = Plot(prange={'x':(-6,6), 'y':(-3,3)})
p.trace(ruta_points(r_azul), color='cornflowerblue')
p.trace(ruta_points(r_verde), color='green')
show(p.pl)

# %% [markdown]
# ## 3. Responde en la siguiente celda

# %% [markdown]
# - ¿A cuántas cuadras de la comisaría se aleja la ruta azul y la verde?
#
#   R:

# %% [markdown]
# ## Ordenemos según cuadras de distancia
#
# Ejecuta la siguiente celda para obtener la cantidad de cuadras que se aleja cada posibilidad.

# %%
# Ejecuta con Ctrl-Enter para ordenar los resultados
n = 3
rutas(n, con_cuadras=True).sort_values('cuadras')

# %% [markdown]
# ## 4. Responde en la siguiente celda

# %% [markdown]
# Si los 3 cachipunes son al azar,
#
# - ¿Es más probable alejarse o acercarse a la comisaría?
#
#   R:
#
# - ¿Cuál es la probabilidad de quedar a 0 cuadras de la comisaría?
#
#   R:

# %% [markdown]
# ## Agrupemos según cuadras de distancia
#
# Usa la siguiente celda para encontrar **grupos de caminos que se alejan la misma cantidad** de cuadras. Primero, define el valor de `n`. Enseguida, ejecuta la celda para agrupar según las cuadras de distancia a la comisaría. Prueba con diferentes valores de `n`.

# %%
# Elige el valor de n
n = 8

# Ok, ejecuta la celda con Ctrl-Enter
r = rutas(n, con_cuadras=True)
por_cuadras(r)

# %% [markdown]
# ## Listo, veamoslo en un gráfico
#
# En la siguiente celda construirás un gráfico de la tabla anterior. El principal interés es en la cantidad de cuadras de distancia a la comisaría. Sera un gráfico de distribución pues veremos la cantidad de caminos posibles para cada cantidad de cuadras.
#
# Prueba con los siguientes valores de `n`:
#
# - `n = 5`
# - `n = 8`
# - `n = 11`

# %%
#Cambia el valor de n
n = 3

#Listo, ejecuta con Ctrl-Enter para graficar
r = rutas(n, con_cuadras=True)
p = ag_plot(por_cuadras(r))
show(p)

# %% [markdown]
# ## 5. Responde en la siguiente celda

# %% [markdown]
# En caso de agrupar para la ruta con n = 8:
#
# - ¿Es más probable volver a la comisaría o alejarse 9 cuadras?
#
#   R:
#
# - ¿Cuál es la cantidad de cuadras de distancia más probable?
#
#   R:
#
# En caso de agrupar para la ruta con n = 11:
#
# - ¿Cuál es la cantidad de cuadras de distancia más probable?
#
#   R:

# %% [markdown]
# ## Anota tu apreciación general de la actividad en la siguiente celda

# %% [markdown]
# NOMBRE DE INTEGRANTES:
#
# - ¿Qué dificultades tuve durante la actividad?
#
#   R:
#
# - ¿Qué ventajas tuvo el utilizar un programa para análisis de experimentos aleatorios?
#
#   R:
#
# - ¿Fueron claras las instrucciones a lo largo de esta actividad?
#
#   R:
#
# - ¿Con qué nota de 1 a 7 evalúo la actividad?
#
#   R:
